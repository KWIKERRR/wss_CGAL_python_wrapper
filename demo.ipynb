# %% [markdown]
# Import

# %%
from weighted_straight_skeleton import compute_straight_skeleton
from utils import ensure_counterclockwise, ensure_clockwise
from utils import load_off_file, visualize_mesh

# %%
base_roof_path = "roof.off"
roof_with_one_hole_path = 'roof_with_one_hole.off'
roof_with_holes_path = 'roof_with_holes.off'
verbose = True

# %%
# Footprint should be in the counterclockwise order
footprint = ensure_counterclockwise([(-10, 10), (-10, -10), (10, -10), (10, 10)])

# angles[0] is associated to edge footprint[0] -> footprint[1]
base_angles = [90, 45, 90, 45]

# The results is saved in a .off file
success = compute_straight_skeleton(footprint, 
                                    angles=base_angles, 
                                    output_file_path=base_roof_path, 
                                    verbose=verbose)

# Returns True/False indicating the success of the computation
print(f'WSS computation succeeded : {success}')
# Out:
# Polygon is counterclockwise
# Polygon with 4 vertices:
# [ WSS computation succeeded : True
# (-10, 10) (-10, -10) (10, -10) (10, 10) ]
# Angles at position 0: [ 45, 90, 45, 90 ]
# Weighted straight skeleton succeed

# %%
vertices, faces = load_off_file(base_roof_path)
visualize_mesh(vertices, faces)

# %%
# Hole points should be in the clockwise order
hole = ensure_clockwise([(-5, 5), (-5, -5), (5, -5), (5, 5)])
hole_angles = [45, 90, 90, 45]

# Base angles and hole angles should be concatenate in one list
roof_with_one_hole_angles = base_angles + hole_angles

compute_straight_skeleton(footprint, 
                          angles=roof_with_one_hole_angles, 
                          output_file_path=roof_with_one_hole_path, 
                          holes_list=[hole], verbose=verbose)
# Out:
# Polygon with 4 vertices:
# True
# [ (-10, 10) (-10, -10) (10, -10) (10, 10) ]
# Angles at position 0: [ 45, 90, 45, 90 ]
# Angles at position 1: [ 45, 45, 90, 90 ]
# Weighted straight skeleton succeed

# %%
vertices, faces = load_off_file(roof_with_one_hole_path)
visualize_mesh(vertices, faces)

# %%
hole1 = ensure_clockwise([(2, 8), (8, 8), (8, 2), (2, 2)])
hole1_angles = [90, 45, 90, 45]

hole2 = ensure_clockwise([(-2, -8), (-8, -8), (-8, -2), (-2, -2)])
hole2_angles = [45, 90, 90, 45]

hole3 = ensure_clockwise([(-2, 8), (-8, 8), (-8, 2), (-2, 2)])
hole3_angles = [45, 90, 45, 90]

hole4 = ensure_clockwise([(2, -8), (8, -8), (8, -2), (2, -2)])
hole4_angles = [90, 90, 45, 45]

holes = [hole1, hole2, hole3, hole4]
roof_with_holes_angle = base_angles + hole1_angles + hole2_angles + hole3_angles + hole4_angles

compute_straight_skeleton(footprint, 
                          angles=roof_with_holes_angle, 
                          output_file_path=roof_with_holes_path, 
                          holes_list=holes, verbose=verbose)
# Out:
# Polygon is clockwise
# Polygon is clockwise
# Polygon with 4 vertices:
# [ (-10, 10) (-10, -10) (10, -10) (10, 10) ]
# Angles at position 0: [ 45, 90, 45, 90 ]
# Angles at position 1: [ 45, 90, 45, 90 ]
# Angles at position 2: [ 45, 45, 90, 90 ]
# Angles at position 3: [ 90, 45, 90, 45 ]
# Angles at position 4: [ 45, 90, 90, 45 ]
# Weighted straight skeleton succeed
# True

# %%
vertices, faces = load_off_file(roof_with_holes_path)
visualize_mesh(vertices, faces)
